# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("menu.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Filet-O-Fish  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
# Category                         260 non-null object
# Item                             260 non-null object
# Serving Size                     260 non-null object
# Calories                         260 non-null int64
# Calories from Fat                260 non-null int64
# Total Fat                        260 non-null float64
# Total Fat (% Daily Value)        260 non-null int64
# Saturated Fat                    260 non-null float64
# Saturated Fat (% Daily Value)    260 non-null int64
# Trans Fat                        260 non-null float64
# Cholesterol                      260 non-null int64
# Cholesterol (% Daily Value)      260 non-null int64
# Sodium                           260 non-null int64
# Sodium (% Daily Value)           260 non-null int64
# Carbohydrates                    260 non-null int64
# Carbohydrates (% Daily Value)    260 non-null int64
# ...

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot.bar()

# %% [markdown]
# # 1. How many calories does the average McDonald's value meal contain?

# %%
df['Calories'].mean()
# Out:
# 368.2692307692308

# %% [markdown]
# # 2. How much do beverages, like soda or coffee, contribute to the overall caloric intake?

# %%
df.pivot_table('Calories','Category').plot(kind='bar',stacked=True,color='r')

# %%
p_table1 = pd.pivot_table(df, values='Calories',index='Category',aggfunc=np.sum)
p_table1
# Out:
#                     Calories
# Category
# Beef & Pork             7410
# Beverages               3070
# Breakfast              22120
# Chicken & Fish         14930
# Coffee & Tea           26970
# Desserts                1555
# Salads                  1620
# Smoothies & Shakes     14880
# Snacks & Sides          3195

# %%
p_table2 = pd.pivot_table(df, values='Calories',index='Category',aggfunc=np.mean)
p_table2
# Out:
#                       Calories
# Category
# Beef & Pork         494.000000
# Beverages           113.703704
# Breakfast           526.666667
# Chicken & Fish      552.962963
# Coffee & Tea        283.894737
# Desserts            222.142857
# Salads              270.000000
# Smoothies & Shakes  531.428571
# Snacks & Sides      245.769231

# %%
amount = df.groupby('Category').sum()
amount_sum = amount[['Calories']].sort_values('Calories',ascending= False)
amount_sum
# Out:
#                     Calories
# Category
# Coffee & Tea           26970
# Breakfast              22120
# Chicken & Fish         14930
# Smoothies & Shakes     14880
# Beef & Pork             7410
# Snacks & Sides          3195
# Beverages               3070
# Salads                  1620
# Desserts                1555

# %%
amount = df.groupby('Category').mean()
amount_mean = amount[['Calories']].sort_values('Calories',ascending= False)
amount_mean
# Out:
#                       Calories
# Category
# Chicken & Fish      552.962963
# Smoothies & Shakes  531.428571
# Breakfast           526.666667
# Beef & Pork         494.000000
# Coffee & Tea        283.894737
# Salads              270.000000
# Snacks & Sides      245.769231
# Desserts            222.142857
# Beverages           113.703704

# %%
p_table1['% of Total Sum'] = round((p_table1.Calories / p_table1.Calories.sum() * 100),2).astype(str) + '%'
p_table1
# Out:
#                     Calories % of Total Sum
# Category
# Beef & Pork             7410          7.74%
# Beverages               3070          3.21%
# Breakfast              22120          23.1%
# Chicken & Fish         14930         15.59%
# Coffee & Tea           26970         28.17%
# Desserts                1555          1.62%
# Salads                  1620          1.69%
# Smoothies & Shakes     14880         15.54%
# Snacks & Sides          3195          3.34%

# %%
p_table1['Percentage of Total'] = round((p_table1.Calories / p_table1.Calories.sum() * 100),2)
p_table1
# Out:
#                     Calories % of Total Sum  Percentage of Total
# Category
# Beef & Pork             7410          7.74%                 7.74
# Beverages               3070          3.21%                 3.21
# Breakfast              22120          23.1%                23.10
# Chicken & Fish         14930         15.59%                15.59
# Coffee & Tea           26970         28.17%                28.17
# Desserts                1555          1.62%                 1.62
# Salads                  1620          1.69%                 1.69
# Smoothies & Shakes     14880         15.54%                15.54
# Snacks & Sides          3195          3.34%                 3.34

# %%
p_table1.pivot_table('Percentage of Total','Category').plot(kind='bar',stacked=True,color='b')

# %%
p_table2['% of Total Mean'] = round((p_table2.Calories / p_table2.Calories.sum() * 100),2).astype(str) + '%'
p_table2
# Out:
#                       Calories % of Total Mean
# Category
# Beef & Pork         494.000000          15.24%
# Beverages           113.703704           3.51%
# Breakfast           526.666667          16.25%
# Chicken & Fish      552.962963          17.06%
# Coffee & Tea        283.894737           8.76%
# Desserts            222.142857           6.86%
# Salads              270.000000           8.33%
# Smoothies & Shakes  531.428571           16.4%
# Snacks & Sides      245.769231           7.58%

# %% [markdown]
# # 3. Does ordered grilled chicken instead of crispy increase a sandwich's nutritional value?

# %%
#grilled_df = df[df.Item.str.contains("Grilled")==True]
#grilled_df

# %%
sandwich_df = df[df.Item.str.contains("Sandwich")==True]
sandwich_df
# Out:
#           Category                                        Item  \
# 57  Chicken & Fish     Premium Crispy Chicken Classic Sandwich
# 58  Chicken & Fish    Premium Grilled Chicken Classic Sandwich
# 59  Chicken & Fish        Premium Crispy Chicken Club Sandwich
# 60  Chicken & Fish       Premium Grilled Chicken Club Sandwich
# 61  Chicken & Fish   Premium Crispy Chicken Ranch BLT Sandwich
# 62  Chicken & Fish  Premium Grilled Chicken Ranch BLT Sandwich
# 63  Chicken & Fish     Bacon Clubhouse Crispy Chicken Sandwich
# 64  Chicken & Fish    Bacon Clubhouse Grilled Chicken Sandwich
# 65  Chicken & Fish      Southern Style Crispy Chicken Sandwich
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 57  7.5 oz (213 g)       510                200       22.0
# 58    7 oz (200 g)       350                 80        9.0
# 59  8.8 oz (249 g)       670                300       33.0
# 60  8.3 oz (235 g)       510                180       20.0
# ...

# %%
grilled_sandwich = sandwich_df[sandwich_df.Item.str.contains("Grilled")==True]
crispy_sandwich = sandwich_df[sandwich_df.Item.str.contains("Crispy")==True]

# %%
grilled_sandwich
# Out:
#           Category                                        Item  \
# 58  Chicken & Fish    Premium Grilled Chicken Classic Sandwich
# 60  Chicken & Fish       Premium Grilled Chicken Club Sandwich
# 62  Chicken & Fish  Premium Grilled Chicken Ranch BLT Sandwich
# 64  Chicken & Fish    Bacon Clubhouse Grilled Chicken Sandwich
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 58    7 oz (200 g)       350                 80        9.0
# 60  8.3 oz (235 g)       510                180       20.0
# 62  7.6 oz (217 g)       450                130       15.0
# 64  9.5 oz (270 g)       590                230       25.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 58                         13            2.0                              9
# 60                         31            7.0                             36
# 62                         23            4.5                             22
# ...

# %%
crispy_sandwich
# Out:
#           Category                                       Item    Serving Size  \
# 57  Chicken & Fish    Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)
# 59  Chicken & Fish       Premium Crispy Chicken Club Sandwich  8.8 oz (249 g)
# 61  Chicken & Fish  Premium Crispy Chicken Ranch BLT Sandwich  8.1 oz (230 g)
# 63  Chicken & Fish    Bacon Clubhouse Crispy Chicken Sandwich   10 oz (284 g)
# 65  Chicken & Fish     Southern Style Crispy Chicken Sandwich  5.6 oz (160 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 57       510                200       22.0                         33
# 59       670                300       33.0                         51
# 61       610                250       28.0                         43
# 63       750                340       38.0                         59
# 65       430                170       19.0                         29
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# ...

# %%
crispy_sandwich1 = crispy_sandwich.drop(index = 65)
crispy_sandwich1
# Out:
#           Category                                       Item    Serving Size  \
# 57  Chicken & Fish    Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)
# 59  Chicken & Fish       Premium Crispy Chicken Club Sandwich  8.8 oz (249 g)
# 61  Chicken & Fish  Premium Crispy Chicken Ranch BLT Sandwich  8.1 oz (230 g)
# 63  Chicken & Fish    Bacon Clubhouse Crispy Chicken Sandwich   10 oz (284 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 57       510                200       22.0                         33
# 59       670                300       33.0                         51
# 61       610                250       28.0                         43
# 63       750                340       38.0                         59
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 57            3.5                             18        0.0           45
# 59            9.0                             44        0.0           85
# ...

# %%
grilled_sandwich1 = grilled_sandwich.drop(['Category','Serving Size'],axis = 1)
crispy_sandwich2 = crispy_sandwich1.drop(['Category','Serving Size'],axis = 1)

# %%
grilled_sandwich2 = grilled_sandwich1.set_index('Item')
crispy_sandwich3 = crispy_sandwich2.set_index('Item')
grilled_sandwich2
# Out:
#                                             Calories  Calories from Fat  \
# Item
# Premium Grilled Chicken Classic Sandwich         350                 80
# Premium Grilled Chicken Club Sandwich            510                180
# Premium Grilled Chicken Ranch BLT Sandwich       450                130
# Bacon Clubhouse Grilled Chicken Sandwich         590                230
#
#                                             Total Fat  \
# Item
# Premium Grilled Chicken Classic Sandwich          9.0
# Premium Grilled Chicken Club Sandwich            20.0
# Premium Grilled Chicken Ranch BLT Sandwich       15.0
# Bacon Clubhouse Grilled Chicken Sandwich         25.0
#
#                                             Total Fat (% Daily Value)  \
# Item
# Premium Grilled Chicken Classic Sandwich                           13
# Premium Grilled Chicken Club Sandwich                              31
# Premium Grilled Chicken Ranch BLT Sandwich                         23
# ...

# %%
grilled_sandwich2.columns
# Out:
# Index(['Calories', 'Calories from Fat', 'Total Fat',
#        'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
new_sandwich = grilled_sandwich1.reset_index(drop=True).merge(crispy_sandwich2.reset_index(drop=True),left_index=True,right_index=True)

# %%
new_sandwich
# Out:
#                                        Item_x  Calories_x  \
# 0    Premium Grilled Chicken Classic Sandwich         350
# 1       Premium Grilled Chicken Club Sandwich         510
# 2  Premium Grilled Chicken Ranch BLT Sandwich         450
# 3    Bacon Clubhouse Grilled Chicken Sandwich         590
#
#    Calories from Fat_x  Total Fat_x  Total Fat (% Daily Value)_x  \
# 0                   80          9.0                           13
# 1                  180         20.0                           31
# 2                  130         15.0                           23
# 3                  230         25.0                           39
#
#    Saturated Fat_x  Saturated Fat (% Daily Value)_x  Trans Fat_x  \
# 0              2.0                                9          0.0
# 1              7.0                               36          0.0
# 2              4.5                               22          0.0
# 3              8.0                               42          0.0
#
# ...

# %%
new_sandwich.columns
# Out:
# Index(['Item_x', 'Calories_x', 'Calories from Fat_x', 'Total Fat_x',
#        'Total Fat (% Daily Value)_x', 'Saturated Fat_x',
#        'Saturated Fat (% Daily Value)_x', 'Trans Fat_x', 'Cholesterol_x',
#        'Cholesterol (% Daily Value)_x', 'Sodium_x', 'Sodium (% Daily Value)_x',
#        'Carbohydrates_x', 'Carbohydrates (% Daily Value)_x', 'Dietary Fiber_x',
#        'Dietary Fiber (% Daily Value)_x', 'Sugars_x', 'Protein_x',
#        'Vitamin A (% Daily Value)_x', 'Vitamin C (% Daily Value)_x',
#        'Calcium (% Daily Value)_x', 'Iron (% Daily Value)_x', 'Item_y',
#        'Calories_y', 'Calories from Fat_y', 'Total Fat_y',
#        'Total Fat (% Daily Value)_y', 'Saturated Fat_y',
#        'Saturated Fat (% Daily Value)_y', 'Trans Fat_y', 'Cholesterol_y',
#        'Cholesterol (% Daily Value)_y', 'Sodium_y', 'Sodium (% Daily Value)_y',
#        'Carbohydrates_y', 'Carbohydrates (% Daily Value)_y', 'Dietary Fiber_y',
# ...

# %%
new_sandwich.drop('Item_y',axis=1)
# Out:
#                                        Item_x  Calories_x  \
# 0    Premium Grilled Chicken Classic Sandwich         350
# 1       Premium Grilled Chicken Club Sandwich         510
# 2  Premium Grilled Chicken Ranch BLT Sandwich         450
# 3    Bacon Clubhouse Grilled Chicken Sandwich         590
#
#    Calories from Fat_x  Total Fat_x  Total Fat (% Daily Value)_x  \
# 0                   80          9.0                           13
# 1                  180         20.0                           31
# 2                  130         15.0                           23
# 3                  230         25.0                           39
#
#    Saturated Fat_x  Saturated Fat (% Daily Value)_x  Trans Fat_x  \
# 0              2.0                                9          0.0
# 1              7.0                               36          0.0
# 2              4.5                               22          0.0
# 3              8.0                               42          0.0
#
# ...

# %%
new_sandwich['Item']=new_sandwich['Item_x'].str.replace("Grilled","")

# %%
new_sandwich = new_sandwich.drop('Item_x',axis=1)

# %%
new_sandwich.index=new_sandwich.Item

# %%
new_sandwich.head()
# Out:
#                                      Calories_x  Calories from Fat_x  \
# Item
# Premium  Chicken Classic Sandwich           350                   80
# Premium  Chicken Club Sandwich              510                  180
# Premium  Chicken Ranch BLT Sandwich         450                  130
# Bacon Clubhouse  Chicken Sandwich           590                  230
#
#                                      Total Fat_x  Total Fat (% Daily Value)_x  \
# Item
# Premium  Chicken Classic Sandwich            9.0                           13
# Premium  Chicken Club Sandwich              20.0                           31
# Premium  Chicken Ranch BLT Sandwich         15.0                           23
# Bacon Clubhouse  Chicken Sandwich           25.0                           39
#
#                                      Saturated Fat_x  \
# Item
# Premium  Chicken Classic Sandwich                2.0
# Premium  Chicken Club Sandwich                   7.0
# ...

# %%
new_sandwich = new_sandwich.drop('Item',axis=1)

# %%
new_sandwich.columns
# Out:
# Index(['Calories_x', 'Calories from Fat_x', 'Total Fat_x',
#        'Total Fat (% Daily Value)_x', 'Saturated Fat_x',
#        'Saturated Fat (% Daily Value)_x', 'Trans Fat_x', 'Cholesterol_x',
#        'Cholesterol (% Daily Value)_x', 'Sodium_x', 'Sodium (% Daily Value)_x',
#        'Carbohydrates_x', 'Carbohydrates (% Daily Value)_x', 'Dietary Fiber_x',
#        'Dietary Fiber (% Daily Value)_x', 'Sugars_x', 'Protein_x',
#        'Vitamin A (% Daily Value)_x', 'Vitamin C (% Daily Value)_x',
#        'Calcium (% Daily Value)_x', 'Iron (% Daily Value)_x', 'Item_y',
#        'Calories_y', 'Calories from Fat_y', 'Total Fat_y',
#        'Total Fat (% Daily Value)_y', 'Saturated Fat_y',
#        'Saturated Fat (% Daily Value)_y', 'Trans Fat_y', 'Cholesterol_y',
#        'Cholesterol (% Daily Value)_y', 'Sodium_y', 'Sodium (% Daily Value)_y',
#        'Carbohydrates_y', 'Carbohydrates (% Daily Value)_y', 'Dietary Fiber_y',
# ...

# %%
new_sandwich1 = new_sandwich

# %%
new_sandwich1.columns = ['Calories_Grilled', 'Calories from Fat_Grilled', 'Total Fat_Grilled',
       'Total Fat (% Daily Value)_Grilled', 'Saturated Fat_Grilled',
       'Saturated Fat (% Daily Value)_Grilled', 'Trans Fat_Grilled', 'Cholesterol_Grilled',
       'Cholesterol (% Daily Value)_Grilled', 'Sodium_Grilled', 'Sodium (% Daily Value)_Grilled',
       'Carbohydrates_Grilled', 'Carbohydrates (% Daily Value)_Grilled', 'Dietary Fiber_Grilled',
       'Dietary Fiber (% Daily Value)_Grilled', 'Sugars_Grilled', 'Protein_Grilled',
       'Vitamin A (% Daily Value)_Grilled', 'Vitamin C (% Daily Value)_Grilled',
       'Calcium (% Daily Value)_Grilled', 'Iron (% Daily Value)_Grilled', 'Item_Crispy',
       'Calories_Crispy', 'Calories from Fat_Crispy', 'Total Fat_Crispy',
       'Total Fat (% Daily Value)_Crispy', 'Saturated Fat_Crispy',
       'Saturated Fat (% Daily Value)_Crispy', 'Trans Fat_Crispy', 'Cholesterol_Crispy',
       'Cholesterol (% Daily Value)_Crispy', 'Sodium_Crispy', 'Sodium (% Daily Value)_Crispy',
       'Carbohydrates_Crispy', 'Carbohydrates (% Daily Value)_Crispy', 'Dietary Fiber_Crispy',
       'Dietary Fiber (% Daily Value)_Crispy', 'Sugars_Crispy', 'Protein_Crispy',
       'Vitamin A (% Daily Value)_Crispy', 'Vitamin C (% Daily Value)_Crispy',
       'Calcium (% Daily Value)_Crispy', 'Iron (% Daily Value)_Crispy']

# %%
#crispy_sort = crispy_sandwich2.sort_values('Calories', ascending=False)
#ax = crispy_sort.plot.barh(x='Item', y='Calories', figsize= (10,7))
#ax.set_title("Total Calories in Crispy Chicken Sandwich(in Cal)")

# %%
#sandwich_forplot = new_sandwich1

# %%
#sandwich_forplot.reset_index(level=0, inplace=True)

# %%
#ax = sandwich_forplot.plot.barh(x='Item', y=['Cholesterol_Grilled','Cholesterol_Crispy'], stacked=False, figsize= (10,10), color=['yellow', 'orange'])
#ax.set_title("Grilled vs Crispy (Cholesterol)")

#for p in ax.patches:
#    left, bottom, width, height = p.get_bbox().bounds
#    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
#                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
new_sandwich1[["Total Fat_Grilled","Total Fat_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Calories_Grilled","Calories_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Calories from Fat_Grilled","Calories from Fat_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Total Fat (% Daily Value)_Grilled","Total Fat (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Saturated Fat_Grilled","Saturated Fat_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Saturated Fat (% Daily Value)_Grilled","Saturated Fat (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Trans Fat_Grilled","Trans Fat_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Cholesterol_Grilled","Cholesterol_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Cholesterol (% Daily Value)_Grilled","Cholesterol (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Sodium_Grilled","Sodium_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Sodium (% Daily Value)_Grilled","Sodium (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Carbohydrates_Grilled","Carbohydrates_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Carbohydrates (% Daily Value)_Grilled","Carbohydrates (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Dietary Fiber_Grilled","Dietary Fiber_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Dietary Fiber (% Daily Value)_Grilled","Dietary Fiber (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Sugars_Grilled","Sugars_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Protein_Grilled","Protein_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Vitamin A (% Daily Value)_Grilled","Vitamin A (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Vitamin C (% Daily Value)_Grilled","Vitamin C (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Calcium (% Daily Value)_Grilled","Calcium (% Daily Value)_Crispy"]].plot(kind="barh")

# %%
new_sandwich1[["Iron (% Daily Value)_Grilled","Iron (% Daily Value)_Crispy"]].plot(kind="barh")

# %% [markdown]
# # 4. What about ordering egg whites instead of whole eggs?

# %%
egg_new_df = df.loc[[3,4,6,7,8,9,12,13,14,15,19,20,22,23,24,25,27,28,29,30,31,32,33,34],:]
egg_new_df
# Out:
#      Category                                               Item  \
# 3   Breakfast                          Sausage McMuffin with Egg
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 6   Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7   Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 12  Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
# 13  Breakfast           Sausage Biscuit with Egg (Large Biscuit)
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15  Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
# 19  Breakfast                     Bacon, Egg & Cheese McGriddles
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 22  Breakfast                   Sausage, Egg & Cheese McGriddles
# ...

# %%
egg_new_df.shape
# Out:
# (24, 24)

# %%
egg_food_df = egg_new_df[~df['Item'].str.contains('Whites')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
egg_food_df.shape
# Out:
# (12, 24)

# %%
egg_white_df = egg_new_df[df['Item'].str.contains('Whites')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
egg_food_df
# Out:
#      Category                                           Item     Serving Size  \
# 3   Breakfast                      Sausage McMuffin with Egg   5.7 oz (161 g)
# 6   Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)   5.3 oz (150 g)
# 7   Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)   5.8 oz (164 g)
# 12  Breakfast     Sausage Biscuit with Egg (Regular Biscuit)   5.7 oz (163 g)
# 13  Breakfast       Sausage Biscuit with Egg (Large Biscuit)   6.2 oz (177 g)
# 19  Breakfast                 Bacon, Egg & Cheese McGriddles   6.1 oz (174 g)
# 22  Breakfast               Sausage, Egg & Cheese McGriddles   7.1 oz (201 g)
# 24  Breakfast                      Bacon, Egg & Cheese Bagel   6.9 oz (197 g)
# 27  Breakfast                Big Breakfast (Regular Biscuit)   9.5 oz (269 g)
# 28  Breakfast                  Big Breakfast (Large Biscuit)    10 oz (283 g)
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)
# ...

# %%
egg_white_df
# Out:
#      Category                                               Item  \
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15  Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 23  Breakfast   Sausage, Egg & Cheese McGriddles with Egg Whites
# 25  Breakfast          Bacon, Egg & Cheese Bagel with Egg Whites
# 29  Breakfast    Big Breakfast with Egg Whites (Regular Biscuit)
# 30  Breakfast      Big Breakfast with Egg Whites (Large Biscuit)
# 33  Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
new_eggs_food = egg_food_df.reset_index(drop=True).merge(egg_white_df.reset_index(drop=True),left_index=True,right_index=True)

# %%
new_eggs_food.columns
# Out:
# Index(['Category_x', 'Item_x', 'Serving Size_x', 'Calories_x',
#        'Calories from Fat_x', 'Total Fat_x', 'Total Fat (% Daily Value)_x',
#        'Saturated Fat_x', 'Saturated Fat (% Daily Value)_x', 'Trans Fat_x',
#        'Cholesterol_x', 'Cholesterol (% Daily Value)_x', 'Sodium_x',
#        'Sodium (% Daily Value)_x', 'Carbohydrates_x',
#        'Carbohydrates (% Daily Value)_x', 'Dietary Fiber_x',
#        'Dietary Fiber (% Daily Value)_x', 'Sugars_x', 'Protein_x',
#        'Vitamin A (% Daily Value)_x', 'Vitamin C (% Daily Value)_x',
#        'Calcium (% Daily Value)_x', 'Iron (% Daily Value)_x', 'Category_y',
#        'Item_y', 'Serving Size_y', 'Calories_y', 'Calories from Fat_y',
#        'Total Fat_y', 'Total Fat (% Daily Value)_y', 'Saturated Fat_y',
#        'Saturated Fat (% Daily Value)_y', 'Trans Fat_y', 'Cholesterol_y',
#        'Cholesterol (% Daily Value)_y', 'Sodium_y', 'Sodium (% Daily Value)_y',
# ...

# %%
new_eggs_food = new_eggs_food.drop(['Item_y','Category_x','Category_y','Serving Size_x','Serving Size_y'],axis=1)

# %%
new_eggs_food
# Out:
#                                            Item_x  Calories_x  \
# 0                       Sausage McMuffin with Egg         450
# 1   Bacon, Egg & Cheese Biscuit (Regular Biscuit)         460
# 2     Bacon, Egg & Cheese Biscuit (Large Biscuit)         520
# 3      Sausage Biscuit with Egg (Regular Biscuit)         510
# 4        Sausage Biscuit with Egg (Large Biscuit)         570
# 5                  Bacon, Egg & Cheese McGriddles         460
# 6                Sausage, Egg & Cheese McGriddles         550
# 7                       Bacon, Egg & Cheese Bagel         620
# 8                 Big Breakfast (Regular Biscuit)         740
# 9                   Big Breakfast (Large Biscuit)         800
# 10  Big Breakfast with Hotcakes (Regular Biscuit)        1090
# 11    Big Breakfast with Hotcakes (Large Biscuit)        1150
#
#     Calories from Fat_x  Total Fat_x  Total Fat (% Daily Value)_x  \
# 0                   250         28.0                           43
# ...

# %%
new_eggs_food.rename(columns = {'Item_x':'Item'}, inplace = True)

# %%
new_eggs_food.index=new_eggs_food.Item

# %%
new_eggs_food.head()
# Out:
#                                                                                         Item  \
# Item
# Sausage McMuffin with Egg                                          Sausage McMuffin with Egg
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)  Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# Bacon, Egg & Cheese Biscuit (Large Biscuit)      Bacon, Egg & Cheese Biscuit (Large Biscuit)
# Sausage Biscuit with Egg (Regular Biscuit)        Sausage Biscuit with Egg (Regular Biscuit)
# Sausage Biscuit with Egg (Large Biscuit)            Sausage Biscuit with Egg (Large Biscuit)
#
#                                                Calories_x  \
# Item
# Sausage McMuffin with Egg                             450
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)         460
# Bacon, Egg & Cheese Biscuit (Large Biscuit)           520
# Sausage Biscuit with Egg (Regular Biscuit)            510
# Sausage Biscuit with Egg (Large Biscuit)              570
#
# ...

# %%
new_eggs_food = new_eggs_food.drop('Item',axis=1)

# %%
new_eggs_food.columns
# Out:
# Index(['Calories_x', 'Calories from Fat_x', 'Total Fat_x',
#        'Total Fat (% Daily Value)_x', 'Saturated Fat_x',
#        'Saturated Fat (% Daily Value)_x', 'Trans Fat_x', 'Cholesterol_x',
#        'Cholesterol (% Daily Value)_x', 'Sodium_x', 'Sodium (% Daily Value)_x',
#        'Carbohydrates_x', 'Carbohydrates (% Daily Value)_x', 'Dietary Fiber_x',
#        'Dietary Fiber (% Daily Value)_x', 'Sugars_x', 'Protein_x',
#        'Vitamin A (% Daily Value)_x', 'Vitamin C (% Daily Value)_x',
#        'Calcium (% Daily Value)_x', 'Iron (% Daily Value)_x', 'Calories_y',
#        'Calories from Fat_y', 'Total Fat_y', 'Total Fat (% Daily Value)_y',
#        'Saturated Fat_y', 'Saturated Fat (% Daily Value)_y', 'Trans Fat_y',
#        'Cholesterol_y', 'Cholesterol (% Daily Value)_y', 'Sodium_y',
#        'Sodium (% Daily Value)_y', 'Carbohydrates_y',
#        'Carbohydrates (% Daily Value)_y', 'Dietary Fiber_y',
#        'Dietary Fiber (% Daily Value)_y', 'Sugars_y', 'Protein_y',
# ...

# %%
new_eggs_food1 = new_eggs_food

# %%
new_eggs_food1.columns = ['Calories', 'Calories from Fat', 'Total Fat',
       'Total Fat (% Daily Value)', 'Saturated Fat',
       'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
       'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
       'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
       'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
       'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
       'Calcium (% Daily Value)', 'Iron (% Daily Value)', 'Calories_Egg Whites',
       'Calories from Fat_Egg Whites', 'Total Fat_Egg Whites', 'Total Fat (% Daily Value)_Egg Whites',
       'Saturated Fat_Egg Whites', 'Saturated Fat (% Daily Value)_Egg Whites', 'Trans Fat_Egg Whites',
       'Cholesterol_Egg Whites', 'Cholesterol (% Daily Value)_Egg Whites', 'Sodium_Egg Whites',
       'Sodium (% Daily Value)_Egg Whites', 'Carbohydrates_Egg Whites',
       'Carbohydrates (% Daily Value)_Egg Whites', 'Dietary Fiber_Egg Whites',
       'Dietary Fiber (% Daily Value)_Egg Whites', 'Sugars_Egg Whites', 'Protein_Egg Whites',
       'Vitamin A (% Daily Value)_Egg Whites', 'Vitamin C (% Daily Value)_Egg Whites',
       'Calcium (% Daily Value)_Egg Whites', 'Iron (% Daily Value)_Egg Whites']

# %%
new_eggs_food1[["Calories","Calories_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Total Fat","Total Fat_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Calories from Fat","Calories from Fat_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Total Fat (% Daily Value)","Total Fat (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Saturated Fat","Saturated Fat_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Saturated Fat (% Daily Value)","Saturated Fat (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Trans Fat","Trans Fat_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Cholesterol","Cholesterol_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Cholesterol (% Daily Value)","Cholesterol (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Sodium","Sodium_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Protein","Protein_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Sodium (% Daily Value)","Sodium (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Carbohydrates","Carbohydrates_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Carbohydrates (% Daily Value)","Carbohydrates (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Dietary Fiber","Dietary Fiber_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Dietary Fiber (% Daily Value)","Dietary Fiber (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Sugars","Sugars_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Vitamin A (% Daily Value)","Vitamin A (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Vitamin C (% Daily Value)","Vitamin C (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Calcium (% Daily Value)","Calcium (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %%
new_eggs_food1[["Iron (% Daily Value)","Iron (% Daily Value)_Egg Whites"]].plot(kind="barh")

# %% [markdown]
# # 5. What is the least number of items could you order from the menu to meet one day's nutritional requirements?

# %%
def div_nzero(n, d):
    return n / d if d else 0

# %%
div_nzero(100,0)
# Out:
# 0

# %%
item_list = []
item_amount = []

for i in df.index:
    f_list = []
    fat = int(div_nzero(100.0 , df.loc[i,'Total Fat (% Daily Value)']))
    satur = int(div_nzero(100.0 , df.loc[i,'Saturated Fat (% Daily Value)']))
    chole = int(div_nzero(100.0 , df.loc[i,'Cholesterol (% Daily Value)']))
    sod = int(div_nzero(100.0 , df.loc[i,'Sodium (% Daily Value)']))
    carbo = int(div_nzero(100.0 , df.loc[i,'Carbohydrates (% Daily Value)']))
    diet = int(div_nzero(100.0 , df.loc[i,'Dietary Fiber (% Daily Value)']))
    vita = int(div_nzero(100.0 , df.loc[i,'Vitamin A (% Daily Value)']))
    vitc = int(div_nzero(100.0 , df.loc[i,'Vitamin C (% Daily Value)']))
    calc = int(div_nzero(100.0 , df.loc[i,'Calcium (% Daily Value)']))
    iron = int(div_nzero(100.0 , df.loc[i,'Iron (% Daily Value)']))
    f_list.extend((fat,satur,chole,sod,carbo,diet,vita,vitc,calc,iron))
    
    print(i,".",df.loc[i,'Item'], "least amount", max(f_list) )
    item_list.append((df.loc[i,'Item']))
    item_amount.append((max(f_list)))
# Out:
# 0 . Egg McMuffin least amount 10
# 1 . Egg White Delight least amount 16
# 2 . Sausage McMuffin least amount 12
# 3 . Sausage McMuffin with Egg least amount 10
# 4 . Sausage McMuffin with Egg Whites least amount 16
# 5 . Steak & Egg McMuffin least amount 50
# 6 . Bacon, Egg & Cheese Biscuit (Regular Biscuit) least amount 14
# 7 . Bacon, Egg & Cheese Biscuit (Large Biscuit) least amount 12
# 8 . Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit) least amount 50
# 9 . Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit) least amount 16
# 10 . Sausage Biscuit (Regular Biscuit) least amount 16
# 11 . Sausage Biscuit (Large Biscuit) least amount 25
# 12 . Sausage Biscuit with Egg (Regular Biscuit) least amount 16
# 13 . Sausage Biscuit with Egg (Large Biscuit) least amount 10
# 14 . Sausage Biscuit with Egg Whites (Regular Biscuit) least amount 16
# 15 . Sausage Biscuit with Egg Whites (Large Biscuit) least amount 25
# ...

# %%
item_amount
# Out:
# [10,
#  16,
#  12,
#  10,
#  16,
#  50,
#  14,
#  12,
#  50,
#  16,
#  16,
#  25,
#  16,
#  10,
#  16,
#  25,
#  50,
#  50,
#  50,
#  11,
#  50,
#  12,
#  11,
#  50,
#  9,
#  10,
#  25,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  14,
#  10,
#  50,
#  50,
#  25,
#  50,
#  50,
#  50,
#  50,
#  16,
#  12,
#  12,
#  50,
#  50,
#  50,
#  50,
#  12,
#  50,
#  16,
#  12,
#  16,
#  50,
#  25,
#  25,
#  12,
#  12,
#  25,
#  25,
#  12,
#  12,
#  50,
#  50,
#  25,
#  50,
#  50,
#  7,
#  7,
#  7,
#  7,
#  6,
#  6,
#  12,
#  12,
#  50,
#  50,
#  50,
#  25,
#  12,
#  50,
#  33,
#  14,
#  33,
#  33,
#  7,
#  11,
#  25,
#  50,
#  50,
#  50,
#  50,
#  50,
#  25,
#  50,
#  50,
#  50,
#  100,
#  100,
#  50,
#  50,
#  50,
#  50,
#  100,
#  33,
#  16,
#  25,
#  7,
#  5,
#  4,
#  11,
#  0,
#  100,
#  100,
#  100,
#  50,
#  33,
#  25,
#  100,
#  33,
#  25,
#  16,
#  50,
#  100,
#  50,
#  33,
#  100,
#  33,
#  50,
#  100,
#  50,
#  25,
#  25,
#  0,
#  0,
#  0,
#  100,
#  0,
#  8,
#  6,
# ...

# %%
least_df = pd.DataFrame(list(zip(item_list,item_amount)),columns=['Item','Least Amount'])

# %%
least_df
# Out:
#                                                   Item  Least Amount
# 0                                         Egg McMuffin            10
# 1                                    Egg White Delight            16
# 2                                     Sausage McMuffin            12
# 3                            Sausage McMuffin with Egg            10
# 4                     Sausage McMuffin with Egg Whites            16
# 5                                 Steak & Egg McMuffin            50
# 6        Bacon, Egg & Cheese Biscuit (Regular Biscuit)            14
# 7          Bacon, Egg & Cheese Biscuit (Large Biscuit)            12
# 8    Bacon, Egg & Cheese Biscuit with Egg Whites (R...            50
# 9    Bacon, Egg & Cheese Biscuit with Egg Whites (L...            16
# 10                   Sausage Biscuit (Regular Biscuit)            16
# 11                     Sausage Biscuit (Large Biscuit)            25
# 12          Sausage Biscuit with Egg (Regular Biscuit)            16
# ...

# %%
df.loc[145,:]
# Out:
# Category                           Coffee & Tea
# Item                             Coffee (Small)
# Serving Size                       12 fl oz cup
# Calories                                      0
# Calories from Fat                             0
# Total Fat                                     0
# Total Fat (% Daily Value)                     0
# Saturated Fat                                 0
# Saturated Fat (% Daily Value)                 0
# Trans Fat                                     0
# Cholesterol                                   0
# Cholesterol (% Daily Value)                   0
# Sodium                                        0
# Sodium (% Daily Value)                        0
# Carbohydrates                                 0
# Carbohydrates (% Daily Value)                 0
# Dietary Fiber                                 0
# Dietary Fiber (% Daily Value)                 0
# Sugars                                        0
# Protein                                       0
# ...

# %%
#import plotly.express as px
#fig = px.scatter(df, x='Protein',y='Sugars', color="Category",size='Calories',
#                 hover_name="Item",trendline="ols",template="plotly_dark",marginal_x="box",marginal_y="box")
#fig.show()

# %%
print('Makanan dengan Kalori tertinggi: {} \n\
       Makanan dengan Lemak tertinggi: {} \n\
       Makanan dengan Kolesterol tertinggi: {} \n\
       Makanan dengan Sodium tertinggi: {} \n\
       Makanan dengan Gula tertinggi: {} \n\
       Makanan dengan Karbohidrat tertinggi: {}'.format(df.Item[df['Calories'].idxmax()],\
                                     df.Item[df['Total Fat'].idxmax()],\
                                     df.Item[df['Cholesterol'].idxmax()],\
                                     df.Item[df['Sodium'].idxmax()],\
                                     df.Item[df['Sugars'].idxmax()],\
                                     df.Item[df['Carbohydrates'].idxmax()]))
# Out:
# Makanan dengan Kalori tertinggi: Chicken McNuggets (40 piece)
#        Makanan dengan Lemak tertinggi: Chicken McNuggets (40 piece)
#        Makanan dengan Kolesterol tertinggi: Big Breakfast with Hotcakes (Regular Biscuit)
#        Makanan dengan Sodium tertinggi: Chicken McNuggets (40 piece)
#        Makanan dengan Gula tertinggi: McFlurry with M&M’s Candies (Medium)
#        Makanan dengan Karbohidrat tertinggi: Chocolate Shake (Large)

# %%
def new_plotc(grouped):
    item = grouped["Item"].sum()
    item_list = item.sort_index()
    item_list = item_list[-20:]
    plt.figure(figsize=(9,10))
    graph = sns.barplot(item_list.index,item_list.values)
    labels = [aj.get_text()[-40:] for aj in graph.get_yticklabels()]
    graph.set_yticklabels(labels)

# %%
kalori = df.groupby(df["Calories"])
new_plotc(kalori)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
new_sandwich1["Calories_Grilled"].mean()
# Out:
# 475.0

# %%
new_sandwich1["Calories_Crispy"].mean()
# Out:
# 635.0

# %%
#sandwich_forplot.to_csv(r'sandwich.csv')

# %%
#eggs_forplot = new_eggs_food1

# %%
#eggs_forplot.reset_index(level=0, inplace=True)

# %%
#eggs_forplot.to_csv(r'egss.csv')

# %%
#new_sandwich1["Cholesterol_Grilled"].mean()

# %%
#new_sandwich1["Cholesterol_Crispy"].mean()

# %%
least_df.loc[least_df['Least Amount'] == 0]
# Out:
#                     Item  Least Amount
# 114    Diet Coke (Small)             0
# 136  Dasani Water Bottle             0
# 137     Iced Tea (Small)             0
# 138    Iced Tea (Medium)             0
# 140     Iced Tea (Child)             0
# 145       Coffee (Small)             0
# 146      Coffee (Medium)             0
# 147       Coffee (Large)             0

# %%
new_df = pd.concat([df, least_df['Least Amount']], axis=1, sort=False)

# %%
least_count = new_df.groupby(new_df["Least Amount"])
new_plotc(least_count)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#new_df.to_csv(r'new_menu.csv')

# %%
least_df.loc[least_df['Least Amount'] == 100]
# Out:
#                                                   Item  Least Amount
# 100                                         Side Salad           100
# 101                                       Apple Slices           100
# 106                                Kids Ice Cream Cone           100
# 115                                 Diet Coke (Medium)           100
# 116                                  Diet Coke (Large)           100
# 117                                  Diet Coke (Child)           100
# 121                                  Dr Pepper (Child)           100
# 126                                     Sprite (Small)           100
# 129                                     Sprite (Child)           100
# 132                   Minute Maid 100% Apple Juice Box           100
# 139                                   Iced Tea (Large)           100
# 143                                  Sweet Tea (Large)           100
# 165                               Nonfat Latte (Large)           100
# ...
